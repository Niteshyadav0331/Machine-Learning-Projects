# %% [markdown]
# <p style = "font-size : 50px; color : #532e1c ; font-family : 'Comic Sans MS'; text-align : center; background-color : #bedcfa; border-radius: 5px 5px;"><strong>Churn Modelling Using ANN</strong></p>

# %%
# necessary imports 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv('../input/churn-modelling/Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #f9b208; border-radius: 5px 5px;"><strong>Exploratory Data Analysis (EDA)</strong></p>

# %%
# checking for null values

df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
values = df.Exited.value_counts()
labels = ['Not Exited', 'Exited']

fig, ax = plt.subplots(figsize = (4, 3), dpi = 100)
explode = (0, 0.09)

patches, texts, autotexts = ax.pie(values, labels = labels, autopct = '%1.2f%%', shadow = True,
                                   startangle = 90, explode = explode)

plt.setp(texts, color = 'grey')
plt.setp(autotexts, size = 8, color = 'white')
autotexts[1].set_color('black')
plt.show()

# %% [markdown]
# <p style = "font-size : 20px; color : #34656d ; font-family : 'Comic Sans MS'; "><strong>20% of the customers have churned and 80% haven't.</strong></p>

# %%
# visualizing categorical variables

fig, ax = plt.subplots(3, 2, figsize = (18, 15))

sns.countplot('Geography', hue = 'Exited', data = df, ax = ax[0][0])
sns.countplot('Gender', hue = 'Exited', data = df, ax = ax[0][1])
sns.countplot('Tenure', hue = 'Exited', data = df, ax = ax[1][0])
sns.countplot('NumOfProducts', hue = 'Exited', data = df, ax = ax[1][1])
sns.countplot('HasCrCard', hue = 'Exited', data = df, ax = ax[2][0])
sns.countplot('IsActiveMember', hue = 'Exited', data = df, ax = ax[2][1])

plt.tight_layout()
plt.show()

# %% [markdown]
# <p style = "font-size : 30px; color : #4e8d7c ; font-family : 'Comic Sans MS';"><strong>From above Plots we can conclude that:-</strong></p>
#
# <ul>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Majority of the customers are from france but most customers which churned are from germany maybe because of lack of resources as there are not many customers.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>The proportion of female customers churning is also greater than that of female customers.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Majority of customers have tenure between 1 to 9 and churing rate is also high between these tenures.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Most of the customers have 1 or 2 products and most customers which churned are having 1 products maybe they are not satisfied so they are churning.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Interestingly, majority of customers that churned are those with credit cards but this can be a coincidence as majority of customers have credit cards.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Unsurprisingly the inactive members have a greater churn and the overall proportion of inactive members is also very high.</strong></li>

# %%
# visualizing continuous variables

fig, ax = plt.subplots(2, 2, figsize = (16, 10))

sns.boxplot(x = 'Exited', y = 'CreditScore', data = df, ax = ax[0][0])
sns.boxplot(x = 'Exited', y = 'Age', data = df, ax = ax[0][1])
sns.boxplot(x = 'Exited', y = 'Balance', data = df, ax = ax[1][0])
sns.boxplot(x = 'Exited', y = 'EstimatedSalary', data = df, ax = ax[1][1])

plt.tight_layout()
plt.show()

# %% [markdown]
# <p style = "font-size : 30px; color : #4e8d7c ; font-family : 'Comic Sans MS';"><strong>From above Plots we can conclude that:-</strong></p>
#
# <ul>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>There is no significant difference in credit score distribution etween custers which are churned or not.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>The older customers are churning more than younger ones.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Bank is loosing customers with significant bank balance.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Estimated Salary does not have a significant on the likelihood to churn.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Interestingly, majority of customers that churned are those with credit cards but this can be a coincidence as majority of customers have credit cards.</strong></li>
#     <li style = "color : #03506f; font-size : 18px; font-family : 'Comic Sans MS';"><strong>Unsurprisingly the inactive members have a greater churn and the overall proportion of inactive members is also very high.</strong></li>

# %%
# heatmap 

plt.figure(figsize = (20, 12))

corr = df.corr()

sns.heatmap(corr, linewidths = 1, annot = True, fmt = ".2f")
plt.show()

# %% [markdown]
# <p style = "font-size : 20px; color : #34656d ; font-family : 'Comic Sans MS'; "><strong>We can say that there is no multicolinearity present in data.</strong></p>

# %%
# dropping useless columns 

df.drop(columns = ['RowNumber', 'CustomerId', 'Surname'], axis = 1, inplace = True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.Geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
# Encoding categorical variables

df['Geography'] = df['Geography'].map({'France' : 0, 'Germany' : 1, 'Spain' : 2})
df['Gender'] = df['Gender'].map({'Male' : 0, 'Female' : 1})

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       1   42       2       0.00              1
# 1          608          2       1   41       1   83807.86              1
# 2          502          0       1   42       8  159660.80              3
# 3          699          0       1   39       1       0.00              2
# 4          850          2       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# creating features and label 

from tensorflow.keras.utils import to_categorical

X = df.drop('Exited', axis = 1)
y = to_categorical(df.Exited)

# %%
# splitting data into training set and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
# Scaling data

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #f9b208; border-radius: 5px 5px;"><strong>Building ANN </strong></p>

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization

# initializing ann
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set 

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# Epoch 1/100
# 188/188 [==============================] - 2s 6ms/step - loss: 0.6554 - accuracy: 0.6800 - val_loss: 0.5726 - val_accuracy: 0.7993
# Epoch 2/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4908 - accuracy: 0.8070 - val_loss: 0.4486 - val_accuracy: 0.8007
# Epoch 3/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4088 - accuracy: 0.8339 - val_loss: 0.3820 - val_accuracy: 0.8547
# Epoch 4/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4017 - accuracy: 0.8336 - val_loss: 0.3544 - val_accuracy: 0.8667
# Epoch 5/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3871 - accuracy: 0.8353 - val_loss: 0.3543 - val_accuracy: 0.8620
# Epoch 6/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.8342 - val_loss: 0.3563 - val_accuracy: 0.8633
# Epoch 7/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3744 - accuracy: 0.8460 - val_loss: 0.3459 - val_accuracy: 0.8673
# Epoch 8/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3699 - accuracy: 0.8441 - val_loss: 0.3445 - val_accuracy: 0.8633
# Epoch 9/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8353 - val_loss: 0.3441 - val_accuracy: 0.8620
# Epoch 10/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3700 - accuracy: 0.8405 - val_loss: 0.3460 - val_accuracy: 0.8647
# Epoch 11/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3667 - accuracy: 0.8473 - val_loss: 0.3434 - val_accuracy: 0.8680
# Epoch 12/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3689 - accuracy: 0.8468 - val_loss: 0.3399 - val_accuracy: 0.8627
# Epoch 13/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3698 - accuracy: 0.8434 - val_loss: 0.3389 - val_accuracy: 0.8647
# Epoch 14/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3709 - accuracy: 0.8434 - val_loss: 0.3359 - val_accuracy: 0.8633
# Epoch 15/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3698 - accuracy: 0.8428 - val_loss: 0.3392 - val_accuracy: 0.8660
# Epoch 16/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3694 - accuracy: 0.8444 - val_loss: 0.3376 - val_accuracy: 0.8673
# Epoch 17/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3836 - accuracy: 0.8361 - val_loss: 0.3483 - val_accuracy: 0.8567
# Epoch 18/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3703 - accuracy: 0.8421 - val_loss: 0.3383 - val_accuracy: 0.8653
# Epoch 19/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.8442 - val_loss: 0.3363 - val_accuracy: 0.8653
# Epoch 20/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3650 - accuracy: 0.8464 - val_loss: 0.3382 - val_accuracy: 0.8660
# Epoch 21/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3693 - accuracy: 0.8414 - val_loss: 0.3389 - val_accuracy: 0.8600
# Epoch 22/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3617 - accuracy: 0.8545 - val_loss: 0.3444 - val_accuracy: 0.8607
# Epoch 23/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3720 - accuracy: 0.8442 - val_loss: 0.3444 - val_accuracy: 0.8587
# Epoch 24/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.8543 - val_loss: 0.3467 - val_accuracy: 0.8553
# Epoch 25/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8451 - val_loss: 0.3375 - val_accuracy: 0.8627
# Epoch 26/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3621 - accuracy: 0.8488 - val_loss: 0.3428 - val_accuracy: 0.8640
# Epoch 27/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8447 - val_loss: 0.3369 - val_accuracy: 0.8667
# Epoch 28/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3577 - accuracy: 0.8533 - val_loss: 0.3374 - val_accuracy: 0.8653
# Epoch 29/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3707 - accuracy: 0.8400 - val_loss: 0.3384 - val_accuracy: 0.8640
# Epoch 30/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8458 - val_loss: 0.3416 - val_accuracy: 0.8600
# Epoch 31/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3726 - accuracy: 0.8385 - val_loss: 0.3410 - val_accuracy: 0.8560
# Epoch 32/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3734 - accuracy: 0.8441 - val_loss: 0.3450 - val_accuracy: 0.8600
# Epoch 33/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3595 - accuracy: 0.8494 - val_loss: 0.3417 - val_accuracy: 0.8613
# Epoch 34/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3655 - accuracy: 0.8451 - val_loss: 0.3359 - val_accuracy: 0.8640
# Epoch 35/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3569 - accuracy: 0.8529 - val_loss: 0.3406 - val_accuracy: 0.8653
# Epoch 36/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.8551 - val_loss: 0.3412 - val_accuracy: 0.8653
# Epoch 37/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3536 - accuracy: 0.8558 - val_loss: 0.3390 - val_accuracy: 0.8647
# Epoch 38/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3578 - accuracy: 0.8492 - val_loss: 0.3418 - val_accuracy: 0.8647
# Epoch 39/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3764 - accuracy: 0.8386 - val_loss: 0.3393 - val_accuracy: 0.8593
# Epoch 40/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3549 - accuracy: 0.8560 - val_loss: 0.3407 - val_accuracy: 0.8660
# Epoch 41/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3577 - accuracy: 0.8489 - val_loss: 0.3515 - val_accuracy: 0.8607
# Epoch 42/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3658 - accuracy: 0.8494 - val_loss: 0.3414 - val_accuracy: 0.8633
# Epoch 43/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8453 - val_loss: 0.3400 - val_accuracy: 0.8627
# Epoch 44/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.8454 - val_loss: 0.3371 - val_accuracy: 0.8680
# Epoch 45/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3629 - accuracy: 0.8469 - val_loss: 0.3351 - val_accuracy: 0.8633
# Epoch 46/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3410 - accuracy: 0.8586 - val_loss: 0.3391 - val_accuracy: 0.8647
# Epoch 47/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3597 - accuracy: 0.8484 - val_loss: 0.3393 - val_accuracy: 0.8613
# Epoch 48/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.8567 - val_loss: 0.3373 - val_accuracy: 0.8593
# Epoch 49/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.8555 - val_loss: 0.3381 - val_accuracy: 0.8633
# Epoch 50/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3558 - accuracy: 0.8494 - val_loss: 0.3335 - val_accuracy: 0.8640
# Epoch 51/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3496 - accuracy: 0.8538 - val_loss: 0.3395 - val_accuracy: 0.8653
# Epoch 52/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3528 - accuracy: 0.8550 - val_loss: 0.3410 - val_accuracy: 0.8660
# Epoch 53/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3599 - accuracy: 0.8454 - val_loss: 0.3369 - val_accuracy: 0.8653
# Epoch 54/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3473 - accuracy: 0.8623 - val_loss: 0.3391 - val_accuracy: 0.8640
# Epoch 55/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3543 - accuracy: 0.8555 - val_loss: 0.3409 - val_accuracy: 0.8647
# Epoch 56/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.8506 - val_loss: 0.3342 - val_accuracy: 0.8613
# Epoch 57/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3671 - accuracy: 0.8488 - val_loss: 0.3328 - val_accuracy: 0.8640
# Epoch 58/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3414 - accuracy: 0.8601 - val_loss: 0.3377 - val_accuracy: 0.8633
# Epoch 59/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.8535 - val_loss: 0.3413 - val_accuracy: 0.8593
# Epoch 60/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3576 - accuracy: 0.8593 - val_loss: 0.3426 - val_accuracy: 0.8587
# Epoch 61/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3630 - accuracy: 0.8518 - val_loss: 0.3394 - val_accuracy: 0.8633
# Epoch 62/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3441 - accuracy: 0.8559 - val_loss: 0.3377 - val_accuracy: 0.8627
# Epoch 63/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3465 - accuracy: 0.8548 - val_loss: 0.3357 - val_accuracy: 0.8640
# Epoch 64/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3651 - accuracy: 0.8484 - val_loss: 0.3357 - val_accuracy: 0.8613
# Epoch 65/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3571 - accuracy: 0.8502 - val_loss: 0.3357 - val_accuracy: 0.8607
# Epoch 66/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3585 - accuracy: 0.8480 - val_loss: 0.3419 - val_accuracy: 0.8593
# Epoch 67/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3697 - accuracy: 0.8391 - val_loss: 0.3409 - val_accuracy: 0.8613
# Epoch 68/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3513 - accuracy: 0.8587 - val_loss: 0.3386 - val_accuracy: 0.8547
# Epoch 69/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3574 - accuracy: 0.8644 - val_loss: 0.3384 - val_accuracy: 0.8620
# Epoch 70/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8622 - val_loss: 0.3381 - val_accuracy: 0.8587
# Epoch 71/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3617 - accuracy: 0.8443 - val_loss: 0.3393 - val_accuracy: 0.8660
# Epoch 72/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3548 - accuracy: 0.8540 - val_loss: 0.3356 - val_accuracy: 0.8627
# Epoch 73/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3506 - accuracy: 0.8592 - val_loss: 0.3370 - val_accuracy: 0.8640
# Epoch 74/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3549 - accuracy: 0.8551 - val_loss: 0.3390 - val_accuracy: 0.8640
# Epoch 75/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3535 - accuracy: 0.8534 - val_loss: 0.3442 - val_accuracy: 0.8640
# Epoch 76/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3520 - accuracy: 0.8475 - val_loss: 0.3382 - val_accuracy: 0.8633
# Epoch 77/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3411 - accuracy: 0.8622 - val_loss: 0.3398 - val_accuracy: 0.8620
# Epoch 78/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3527 - accuracy: 0.8550 - val_loss: 0.3396 - val_accuracy: 0.8667
# Epoch 79/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3452 - accuracy: 0.8575 - val_loss: 0.3406 - val_accuracy: 0.8573
# Epoch 80/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3613 - accuracy: 0.8492 - val_loss: 0.3368 - val_accuracy: 0.8627
# Epoch 81/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3647 - accuracy: 0.8472 - val_loss: 0.3367 - val_accuracy: 0.8640
# Epoch 82/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.8508 - val_loss: 0.3384 - val_accuracy: 0.8600
# Epoch 83/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3604 - accuracy: 0.8470 - val_loss: 0.3350 - val_accuracy: 0.8653
# Epoch 84/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3508 - accuracy: 0.8586 - val_loss: 0.3384 - val_accuracy: 0.8647
# Epoch 85/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3672 - accuracy: 0.8444 - val_loss: 0.3324 - val_accuracy: 0.8680
# Epoch 86/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3621 - accuracy: 0.8523 - val_loss: 0.3326 - val_accuracy: 0.8687
# Epoch 87/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 0.8517 - val_loss: 0.3347 - val_accuracy: 0.8647
# Epoch 88/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3492 - accuracy: 0.8601 - val_loss: 0.3337 - val_accuracy: 0.8640
# Epoch 89/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3510 - accuracy: 0.8529 - val_loss: 0.3397 - val_accuracy: 0.8607
# Epoch 90/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3532 - accuracy: 0.8583 - val_loss: 0.3485 - val_accuracy: 0.8573
# Epoch 91/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3460 - accuracy: 0.8563 - val_loss: 0.3394 - val_accuracy: 0.8660
# Epoch 92/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3618 - accuracy: 0.8490 - val_loss: 0.3367 - val_accuracy: 0.8620
# Epoch 93/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3540 - accuracy: 0.8574 - val_loss: 0.3380 - val_accuracy: 0.8653
# Epoch 94/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.8467 - val_loss: 0.3362 - val_accuracy: 0.8667
# Epoch 95/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3388 - accuracy: 0.8610 - val_loss: 0.3329 - val_accuracy: 0.8587
# Epoch 96/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3482 - accuracy: 0.8637 - val_loss: 0.3364 - val_accuracy: 0.8627
# Epoch 97/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3573 - accuracy: 0.8551 - val_loss: 0.3442 - val_accuracy: 0.8607
# Epoch 98/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3549 - accuracy: 0.8598 - val_loss: 0.3385 - val_accuracy: 0.8640
# Epoch 99/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3577 - accuracy: 0.8578 - val_loss: 0.3358 - val_accuracy: 0.8620
# Epoch 100/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8499 - val_loss: 0.3401 - val_accuracy: 0.8640

# %% [markdown]
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #f9b208; border-radius: 5px 5px;"><strong>Visualizing Training and Validation Loss</strong></p>

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss'] 
epoch = range(1, 101)
sns.lineplot(epoch, train_loss, label = 'Training Loss')
sns.lineplot(epoch, val_loss, label = 'Validation Loss')
plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #f9b208; border-radius: 5px 5px;"><strong>Visualizing Training and Validation accuracy</strong></p>

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['accuracy']
val_loss = model_history.history['val_accuracy'] 
epoch = range(1, 101)
sns.lineplot(epoch, train_loss, label = 'Training accuracy')
sns.lineplot(epoch, val_loss, label = 'Validation accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 [==============================] - 0s 872us/step - loss: 0.3380 - accuracy: 0.8656
# Accuracy of model is 0.8655999898910522

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                110
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 10)                40
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 77
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7)                 0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7)                 28
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 16
# =================================================================
# Total params: 271
# Trainable params: 237
# Non-trainable params: 34
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes = True)

# %% [markdown]
# <p style = "font-size : 25px; color : #f55c47 ; font-family : 'Comic Sans MS'; "><strong>If you like my work, please do Upvote.</strong></p>
